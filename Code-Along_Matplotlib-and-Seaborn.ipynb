# %% [markdown]
# # Data Visualization Code-Along - Using Matplotlib and Seaborn

# %% [markdown]
# ### Imports and Data

# %%
# Data manipulation
import pandas as pd

# Math
import numpy as np
# Set seed for reproducability
np.random.seed(2019)

# Data visualization - helps customize plots
import matplotlib.pyplot as plt
# Setting our matplotlib settings
# %matplotlib inline

# Prettier data visualization
import seaborn as sns
# Setting a default style for our seaborn plots
# sns.set(style = 'darkgrid')

# %%
# Before reading in a csv file, we can check what's in our current directory
# !ls
# Out:
# Austin_Animal_Center_Intakes.csv        lessonplan-viz1.md
# Clean-Austin_Animal_Center_Intakes.csv  matplotlib-intro.ipynb
# Code-Along_Matplotlib-and-Seaborn.ipynb music_pie_chart.jpeg
# README.md                               pre_process_animal_shelter_data.py
# __pycache__                             shelter-pups.jpeg
# barplot-vs-histogram.png

# %%
# Reading in our csv
df = pd.read_csv("Clean-Austin_Animal_Center_Intakes.csv")

# %%
# Examining our csv
df.head()
# Out:
#   animal_id DateTime_intake                    Found Location    Intake Type  \
# 0   A792908      2019-04-16      10505 S Ih 35 in Austin (TX)  Public Assist
# 1   A488234      2019-04-16         Clear Veiw in Travis (TX)  Public Assist
# 2   A792904      2019-04-16    9808 Crownridge in Austin (TX)          Stray
# 3   A792902      2019-04-16  2412 Bitter Creek in Austin (TX)          Stray
# 4   A792899      2019-04-16  2412 Bitter Creek in Austin (TX)          Stray
#
#   Intake Condition Animal Type_intake Age upon Intake  year  month_intake  \
# 0           Normal              Other          1 year  2019             4
# 1           Normal                Dog        13 years  2019             4
# 2           Normal                Dog        4 months  2019             4
# 3           Normal                Cat          1 week  2019             4
# 4           Normal                Cat          1 week  2019             4
#
#    day_intake  ... Date of Birth     Outcome Type Animal Type_outcome  \
# 0          16  ...    04/16/2018       Euthanasia               Other
# 1          16  ...    10/02/2005  Return to Owner                 Dog
# 2          16  ...    11/16/2018         Transfer                 Dog
# 3          16  ...    04/09/2019         Transfer                 Cat
# 4          16  ...    04/09/2019         Transfer                 Cat
#
#   Sex upon Outcome Age upon Outcome                               Breed  \
# 0          Unknown           1 year                             Bat Mix
# 1    Neutered Male         13 years  German Shepherd/Labrador Retriever
# 2    Neutered Male         5 months                         Pointer Mix
# 3          Unknown          1 weeks              Domestic Shorthair Mix
# 4          Unknown          1 weeks              Domestic Shorthair Mix
#
#           Color month_outcome day_outcome  days_in_shelter
# 0         Brown           4.0        17.0                1
# 1   Brown/Black           4.0        24.0                8
# 2   Black/White           4.0        24.0                8
# 3          Buff           4.0        18.0                2
# 4  Orange Tabby           4.0        18.0                2
#
# [5 rows x 22 columns]

# %%
# More ways of examining our csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86764 entries, 0 to 86763
# Data columns (total 22 columns):
# animal_id              86764 non-null object
# DateTime_intake        86764 non-null object
# Found Location         86764 non-null object
# Intake Type            86764 non-null object
# Intake Condition       86764 non-null object
# Animal Type_intake     86764 non-null object
# Age upon Intake        86764 non-null object
# year                   86764 non-null int64
# month_intake           86764 non-null int64
# day_intake             86764 non-null int64
# Name                   65599 non-null object
# DateTime_outcome       86764 non-null object
# Date of Birth          86764 non-null object
# Outcome Type           86761 non-null object
# Animal Type_outcome    86764 non-null object
# Sex upon Outcome       86762 non-null object
# Age upon Outcome       86763 non-null object
# Breed                  86764 non-null object
# Color                  86764 non-null object
# month_outcome          86764 non-null float64
# day_outcome            86764 non-null float64
# days_in_shelter        86764 non-null int64
# dtypes: float64(2), int64(4), object(16)
# memory usage: 14.6+ MB

# %%
# Still more ways to examine our csv
df.describe()
# Out:
#                year  month_intake    day_intake  month_outcome   day_outcome  \
# count  86764.000000  86764.000000  86764.000000   86764.000000  86764.000000
# mean    2016.029817      6.257180     15.389459       6.935872     16.077279
# std        1.615893      3.291534      8.735011       3.307431      8.723639
# min     2013.000000      1.000000      1.000000       1.000000      1.000000
# 25%     2015.000000      3.000000      8.000000       4.000000      9.000000
# 50%     2016.000000      6.000000     15.000000       7.000000     16.000000
# 75%     2017.000000      9.000000     23.000000      10.000000     24.000000
# max     2019.000000     12.000000     31.000000      12.000000     31.000000
#
#        days_in_shelter
# count     86764.000000
# mean         21.336303
# std          36.933167
# min           1.000000
# 25%           4.000000
# 50%           7.000000
# 75%          22.000000
# max         356.000000

# %% [markdown]
# ### [Barplots:](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.bar.html)
#
# Barplots are used for displaying one dimensional, discrete data.
#
# "One axis of a bar graph features the categories being compared, while the other axis represents the value of each. The length of each bar is proportionate to the value it represents." [(source)](https://visme.co/blog/types-of-graphs/#i7IKQBydAHvVADcl.99)
#
# Call plt.bar with at least two arguments:
#
# - x: a list of categories
# - height: a value for each category

# %% [markdown]
# #### Task 1:
# Create a bar chart showing the number of days in shelter for five named dogs.

# %%
# Step one: grab all dogs
dog_df = df.loc[df["Animal Type_intake"] == "Dog"]

# Also fine:
# dog_df = df.groupby('Animal Type_intake').get_group('Dog')

dog_df.head()
# Out:
#    animal_id DateTime_intake                     Found Location  \
# 1    A488234      2019-04-16          Clear Veiw in Travis (TX)
# 2    A792904      2019-04-16     9808 Crownridge in Austin (TX)
# 10   A792900      2019-04-16  Payton Falls Drive in Austin (TX)
# 11   A792900      2019-04-16  Payton Falls Drive in Austin (TX)
# 12   A790139      2019-04-16                        Austin (TX)
#
#         Intake Type Intake Condition Animal Type_intake Age upon Intake  year  \
# 1     Public Assist           Normal                Dog        13 years  2019
# 2             Stray           Normal                Dog        4 months  2019
# 10            Stray           Normal                Dog        2 months  2019
# 11            Stray           Normal                Dog        2 months  2019
# 12  Owner Surrender           Normal                Dog        2 months  2019
#
#     month_intake  day_intake  ... Date of Birth     Outcome Type  \
# 1              4          16  ...    10/02/2005  Return to Owner
# 2              4          16  ...    11/16/2018         Transfer
# 10             4          16  ...    02/10/2019         Adoption
# 11             4          16  ...    02/10/2019         Adoption
# 12             4          16  ...    02/13/2019         Adoption
#
#    Animal Type_outcome Sex upon Outcome Age upon Outcome  \
# 1                  Dog    Neutered Male         13 years
# 2                  Dog    Neutered Male         5 months
# 10                 Dog    Neutered Male         2 months
# 11                 Dog    Neutered Male         2 months
# 12                 Dog    Neutered Male         2 months
#
#                                  Breed        Color month_outcome day_outcome  \
# 1   German Shepherd/Labrador Retriever  Brown/Black           4.0        24.0
# 2                          Pointer Mix  Black/White           4.0        24.0
# 10                 Anatol Shepherd Mix  White/Brown           4.0        26.0
# 11                 Anatol Shepherd Mix  White/Brown           4.0        21.0
# 12      German Shepherd/Great Pyrenees        Black           4.0        17.0
#
#     days_in_shelter
# 1                 8
# 2                 8
# 10               10
# 11                5
# 12                1
#
# [5 rows x 22 columns]

# %%
# Step two: grab all named dogs
named_dogs_df = dog_df.loc[dog_df["Name"].isna() != True]
named_dogs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45793 entries, 1 to 86762
# Data columns (total 22 columns):
# animal_id              45793 non-null object
# DateTime_intake        45793 non-null object
# Found Location         45793 non-null object
# Intake Type            45793 non-null object
# Intake Condition       45793 non-null object
# Animal Type_intake     45793 non-null object
# Age upon Intake        45793 non-null object
# year                   45793 non-null int64
# month_intake           45793 non-null int64
# day_intake             45793 non-null int64
# Name                   45793 non-null object
# DateTime_outcome       45793 non-null object
# Date of Birth          45793 non-null object
# Outcome Type           45792 non-null object
# Animal Type_outcome    45793 non-null object
# Sex upon Outcome       45791 non-null object
# Age upon Outcome       45792 non-null object
# Breed                  45793 non-null object
# Color                  45793 non-null object
# month_outcome          45793 non-null float64
# day_outcome            45793 non-null float64
# days_in_shelter        45793 non-null int64
# dtypes: float64(2), int64(4), object(16)
# memory usage: 8.0+ MB

# %%
# Step three: grab five
first_five = named_dogs_df.head()
first_five["Name"]
# Out:
# 1       Spot
# 2       *Leo
# 12      Peep
# 13     Zymba
# 16    Canelo
# Name: Name, dtype: object

# %%
# Set your x and y axes/variables
five_dog_names = first_five["Name"]
five_dog_shelterdays = first_five["days_in_shelter"]

# %%
# Make a bar plot!
plt.bar(five_dog_names, five_dog_shelterdays)

plt.show()

# %%
# Okay, now improve/prettify your bar plot. Titles, labels, etc.
plt.figure(figsize=(12,8))

plt.bar(five_dog_names, five_dog_shelterdays, color="green")

plt.title("Number of Days Each Dog Spent In Shelter")
plt.xlabel("Dogs")
plt.ylabel("Number of Days")

plt.show()

# %% [markdown]
# So what? What does this show you? What kind of information can you glean from a bar graph?

# %% [markdown]
# ### [Histograms:](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html)
#
# Histograms are like barplots in the sense that they describe one-dimensional data. However, a histogram divides the data into bins, counts the number of observations in each bin, and shows the bins on the x-axis and the frequency on the y-axis. It is used for visualizing continuous variables.
#
# ![barplot-vs-histogram.png](attachment:barplot-vs-histogram.png)
#
# Call plt.hist with at least one argument:
#
# - x: the input/variable to be counted

# %% [markdown]
# #### Task 2:
# Create a histogram showing how many days that dogs spend in shelter.

# %%
# Make sure you have your dog data, or grab that now
dog_df.head()
# Out:
#    animal_id DateTime_intake                     Found Location  \
# 1    A488234      2019-04-16          Clear Veiw in Travis (TX)
# 2    A792904      2019-04-16     9808 Crownridge in Austin (TX)
# 10   A792900      2019-04-16  Payton Falls Drive in Austin (TX)
# 11   A792900      2019-04-16  Payton Falls Drive in Austin (TX)
# 12   A790139      2019-04-16                        Austin (TX)
#
#         Intake Type Intake Condition Animal Type_intake Age upon Intake  year  \
# 1     Public Assist           Normal                Dog        13 years  2019
# 2             Stray           Normal                Dog        4 months  2019
# 10            Stray           Normal                Dog        2 months  2019
# 11            Stray           Normal                Dog        2 months  2019
# 12  Owner Surrender           Normal                Dog        2 months  2019
#
#     month_intake  day_intake  ... Date of Birth     Outcome Type  \
# 1              4          16  ...    10/02/2005  Return to Owner
# 2              4          16  ...    11/16/2018         Transfer
# 10             4          16  ...    02/10/2019         Adoption
# 11             4          16  ...    02/10/2019         Adoption
# 12             4          16  ...    02/13/2019         Adoption
#
#    Animal Type_outcome Sex upon Outcome Age upon Outcome  \
# 1                  Dog    Neutered Male         13 years
# 2                  Dog    Neutered Male         5 months
# 10                 Dog    Neutered Male         2 months
# 11                 Dog    Neutered Male         2 months
# 12                 Dog    Neutered Male         2 months
#
#                                  Breed        Color month_outcome day_outcome  \
# 1   German Shepherd/Labrador Retriever  Brown/Black           4.0        24.0
# 2                          Pointer Mix  Black/White           4.0        24.0
# 10                 Anatol Shepherd Mix  White/Brown           4.0        26.0
# 11                 Anatol Shepherd Mix  White/Brown           4.0        21.0
# 12      German Shepherd/Great Pyrenees        Black           4.0        17.0
#
#     days_in_shelter
# 1                 8
# 2                 8
# 10               10
# 11                5
# 12                1
#
# [5 rows x 22 columns]

# %%
# Define your input variable
dog_shelterdays = dog_df["days_in_shelter"]

# %%
# Let's go ahead and throw that into a histogram!
plt.hist(dog_shelterdays)

plt.show()

# %%
# Interpret that histogram by adding a title and x/y labels
# Change around the number of bins, too - how does that change perspective?
plt.figure(figsize=(12,8))

plt.hist(dog_shelterdays, bins=100)

plt.title("How long are dogs in shelters?")
plt.xlabel("Number of Days")
plt.ylabel("Number of Dogs")
plt.xticks(np.arange(0,360, step=20))

plt.show()

# %% [markdown]
# Again, so what? What does this tell you?

# %% [markdown]
# Compare to a normal random distribution (https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.random.randn.html)

# %%
# Generate 1000 values
x = np.random.randn(1000)

# Plot the histogram
plt.hist(x, bins=20)

# Labels
plt.xlabel('Number of Standard Deviations')
plt.ylabel('Frequency of Values')
plt.title('Histogram - Normal Random Distribution')

plt.show()

# %% [markdown]
# ### [Scatterplot:](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html)
#
# Scatterplots visualize two dimensional data (observations with two variables). It allows us to examine the relationship between two variables.
#
# Call plt.scatter with at least two arguments:
#
# - x: first variable
# - y: second variable

# %% [markdown]
# #### Task 3:
# Create a scatter plot to compare the age of a dog, in days, to the number of days spent in shelter.

# %%
# Need to do some data wrangling to get there! Look at "Age upon Outcome", why
# is that harder to use than calculating an age in days?
dog_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53745 entries, 1 to 86762
# Data columns (total 22 columns):
# animal_id              53745 non-null object
# DateTime_intake        53745 non-null object
# Found Location         53745 non-null object
# Intake Type            53745 non-null object
# Intake Condition       53745 non-null object
# Animal Type_intake     53745 non-null object
# Age upon Intake        53745 non-null object
# year                   53745 non-null int64
# month_intake           53745 non-null int64
# day_intake             53745 non-null int64
# Name                   45793 non-null object
# DateTime_outcome       53745 non-null datetime64[ns]
# Date of Birth          53745 non-null object
# Outcome Type           53744 non-null object
# Animal Type_outcome    53745 non-null object
# Sex upon Outcome       53743 non-null object
# Age upon Outcome       53744 non-null object
# Breed                  53745 non-null object
# Color                  53745 non-null object
# month_outcome          53745 non-null float64
# day_outcome            53745 non-null float64
# days_in_shelter        53745 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(15)
# memory usage: 11.9+ MB

# %%
# Convert the outcome date to datetime
# Converting to datetime will likely result in a setting with copy warning
# I hate those. Check out this link for when/why you should care about them,
# though: https://www.dataquest.io/blog/settingwithcopywarning/

dog_df["DateTime_outcome"] = pd.to_datetime(dog_df["DateTime_outcome"],
                                            format="%Y-%m-%d")

# %%
# Convert date of birth to datetime
dog_df["Date of Birth"] = pd.to_datetime(dog_df["Date of Birth"],
                                         format="%m/%d/%Y")

# %%
# Get age in days
dog_df["Age_in_Years"] = (dog_df["DateTime_outcome"] -
                          dog_df["Date of Birth"]).dt.days

# %%
# Plot your scatterplot! Anything wrong with this? See anything weird?
plt.figure(figsize=(12,8))
plt.scatter(dog_df["Age_in_Years"], dog_df["days_in_shelter"])
plt.show()

# %%
dog_df.loc[dog_df["Age_in_Years"] < 0]
# Out:
#       animal_id DateTime_intake                      Found Location  \
# 2908    A788874      2019-02-10         7300 Fm 2222 in Austin (TX)
# 2913    A788866      2019-02-10  7710 Blue Goose Road in Manor (TX)
# 32859   A745085      2017-03-12  10600 Winchelsea Ct in Austin (TX)
# 49091   A754280      2016-02-27        4502 Kind Way in Travis (TX)
# 59319   A753893      2015-06-26    6709 Ponca Street in Austin (TX)
# 61412   A703416      2015-05-24     11505 Melstone Dr in Manor (TX)
# 72025   A751749      2014-09-09                         Austin (TX)
#
#            Intake Type Intake Condition Animal Type_intake Age upon Intake  \
# 2908             Stray           Normal                Dog         0 years
# 2913             Stray           Normal                Dog         0 years
# 32859  Owner Surrender           Normal                Dog         0 years
# 49091  Owner Surrender           Normal                Dog         0 years
# 59319            Stray           Normal                Dog        -1 years
# 61412            Stray           Normal                Dog         0 years
# 72025  Owner Surrender           Normal                Dog         0 years
#
#        year  month_intake  day_intake  ...     Outcome Type  \
# 2908   2019             2          10  ...         Adoption
# 2913   2019             2          10  ...         Adoption
# 32859  2017             3          12  ...         Adoption
# 49091  2016             2          27  ...         Transfer
# 59319  2015             6          26  ...         Transfer
# 61412  2015             5          24  ...  Return to Owner
# 72025  2014             9           9  ...         Adoption
#
#       Animal Type_outcome Sex upon Outcome Age upon Outcome  \
# 2908                  Dog    Spayed Female          0 years
# 2913                  Dog    Neutered Male          0 years
# 32859                 Dog    Spayed Female          0 years
# 49091                 Dog      Intact Male          0 years
# 59319                 Dog      Intact Male         -1 years
# 61412                 Dog    Neutered Male          0 years
# 72025                 Dog    Neutered Male          0 years
#
#                            Breed           Color month_outcome day_outcome  \
# 2908      Labrador Retriever Mix  White/Tricolor           2.0        14.0
# 2913   German Shepherd/Catahoula   Black Brindle           2.0        15.0
# 32859  Australian Cattle Dog Mix           White           3.0        13.0
# 49091      Australian Cattle Dog     Black/Brown           4.0        11.0
# 59319       American Bulldog Mix     White/Brown           7.0         2.0
# 61412     Labrador Retriever Mix           Black           5.0        26.0
# 72025          Border Collie Mix     Black/White           9.0        10.0
#
#       days_in_shelter  Age_in_Years
# 2908                4          -295
# 2913                5          -294
# 32859               1          -212
# 49091              44           -92
# 59319               6          -376
# 61412               2            -3
# 72025               1           -93
#
# [7 rows x 23 columns]

# %%
dog_df["Age_in_Years"].describe()
# Out:
# count    53745.000000
# mean       974.836022
# std       1051.693595
# min       -376.000000
# 25%        284.000000
# 50%        727.000000
# 75%       1213.000000
# max       7305.000000
# Name: Age_in_Years, dtype: float64

# %% [markdown]
# Why was it useful to do a scatterplot in this instance? What other uses can you think of for using a scatterplot?

# %% [markdown]
# ### And now, [Seaborn:](https://seaborn.pydata.org/)

# %% [markdown]
# #### Task 4:
# Create a pairplot to examine our variables.

# %%
# Apply a basic pairplot
sns.pairplot(dog_df)

# %%
# Now use the hue argument
sns.pairplot(df, hue = 'Animal Type_intake')

# %% [markdown]
# What is a pairplot doing? Why is it useful, and when would it not be useful? What isn't in this plot?

# %% [markdown]
# ### Sources!
#
# Types of plots: some comparisons and descriptions from [visme.co](https://visme.co/blog/types-of-graphs/)
#
# ### Further reading
#
# - When to use pairplots, and how to make them more useful: [Towards Data Science](https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166)
# - The ultimate Seaborn tutorial (cannot recommend this enough): [Elite Data Science](https://elitedatascience.com/python-seaborn-tutorial)
# - Understanding the SettingWithCopyWarning: [Dataquest](https://www.dataquest.io/blog/settingwithcopywarning/)
